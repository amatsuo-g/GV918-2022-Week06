# %% [markdown]
# <a href="https://colab.research.google.com/github/amatsuo-g/GV918-2022-Week06/blob/main/Week06_Demo_2_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tasks
#
# In this part of demo, we will extract information from two websites:
#
# - https://en.wikipedia.org/wiki/International_court
# - https://www.europarl.europa.eu/meps/en/full-list/a

# %% [markdown]
# # Load packages

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # International court
#
# - Scenario 1

# %% [markdown]
# ## Extract the first tables using `pandas`

# %%
df_tables = pd.read_html("https://en.wikipedia.org/wiki/International_court")

# %%
len(df_tables)
# Out:
# 4

# %%
df_tables[0].head()
# Out:
#                                              Name  \
# 0      African Court on Human and Peoples' Rights
# 1  Appellate Body of the World Trade Organization
# 2                        Benelux Court of Justice
# 3                      Caribbean Court of Justice
# 4                              CIS Economic Court
#
#                             Subject matter and scope  \
# 0              Human rights within the African Union
# 1  Trade disputes within the World Trade Organiza...
# 2                  Trade disputes within the Benelux
# 3    General disputes within the Caribbean Community
# 4  Trade disputes and interpretation of treaties ...
#
#                                         Headquarters  Years active
# 0  Addis Ababa, Ethiopia (2006–7)Arusha, Tanzania...  2006–present
# 1                                Geneva, Switzerland  1995–present
# 2                                  Brussels, Belgium  1975–present
# 3                 Port of Spain, Trinidad and Tobago  2005–present
# 4                                     Minsk, Belarus  1994–present

# %%
df_ic = df_tables[0]

# %%
df_ic
# Out:
#                                                  Name  \
# 0          African Court on Human and Peoples' Rights
# 1      Appellate Body of the World Trade Organization
# 2                            Benelux Court of Justice
# 3                          Caribbean Court of Justice
# 4                                  CIS Economic Court
# 5                             COMESA Court of Justice
# 6   Common Court of Justice and Arbitration of the...
# 7            Court of Justice of the Andean Community
# 8                Court of the Eurasian Economic Union
# 9                       East African Court of Justice
# 10                    Eastern Caribbean Supreme Court
# 11                            ECOWAS Court of Justice
# 12                     European Court of Human Rights
# 13                          European Court of Justice
# 14              European Free Trade Association Court
# 15                   European Nuclear Energy Tribunal
# 16               Inter-American Court of Human Rights
# 17                     International Court of Justice
# 18                       International Criminal Court
# 19         International Criminal Tribunal for Rwanda
# 20  International Criminal Tribunal for the former...
# 21                    International Military Tribunal
# 22   International Military Tribunal for the Far East
# 23  International Residual Mechanism for Criminal ...
# 24      International Tribunal for the Law of the Sea
# 25           Permanent Court of International Justice
# 26            Residual Special Court for Sierra Leone
# 27                                      SADC Tribunal
# 28                     Special Court for Sierra Leone
# 29                       Special Tribunal for Lebanon
#
#                              Subject matter and scope  \
# 0               Human rights within the African Union
# 1   Trade disputes within the World Trade Organiza...
# 2                   Trade disputes within the Benelux
# 3     General disputes within the Caribbean Community
# 4   Trade disputes and interpretation of treaties ...
# 5   Trade disputes within the Common Market for Ea...
# 6   Interpretation of OHADA treaties and uniform laws
# 7          Trade disputes within the Andean Community
# 8   Trade disputes and interpretation of treaties ...
# 9   Interpretation of East African Community treaties
# 10  General disputes within the Organisation of Ea...
# 11  Interpretation of Economic Community of West A...
# 12          Human rights within the Council of Europe
# 13               Interpretation of European Union law
# 14  Interpretation of European Free Trade Associat...
# 15            Nuclear energy disputes within the OECD
# 16  Human rights within the Organization of Americ...
# 17                     General disputes globally (UN)
# 18      Criminal prosecutions globally (Rome Statute)
# 19  Criminal prosecutions for the Rwandan genocide...
# 20   Criminal prosecutions for the Yugoslav Wars (UN)
# 21  Criminal prosecutions of Nazi German officials...
# 22  Criminal prosecutions of Imperial Japanese off...
# 23  Completing the Rwanda and Yugoslav Tribunals' ...
# 24                Maritime disputes globally (UNCLOS)
# 25      General disputes globally (League of Nations)
# 26  Completing the Special Court for Sierra Leone'...
# 27  Interpretation of Southern African Development...
# 28  Criminal prosecutions for the Sierra Leone Civ...
# 29  Criminal prosecutions for the assassination of...
#
#                                          Headquarters  Years active
# 0   Addis Ababa, Ethiopia (2006–7)Arusha, Tanzania...  2006–present
# 1                                 Geneva, Switzerland  1995–present
# 2                                   Brussels, Belgium  1975–present
# 3                  Port of Spain, Trinidad and Tobago  2005–present
# 4                                      Minsk, Belarus  1994–present
# 5                                     Khartoum, Sudan  1998–present
# 6                                Abidjan, Ivory Coast  1998–present
# 7                                      Quito, Ecuador  1983–present
# 8                                      Minsk, Belarus  2015–present
# 9                                    Arusha, Tanzania  2001–present
# 10                              Castries, Saint Lucia  1967–present
# 11                                     Abuja, Nigeria  1996–present
# 12                                 Strasbourg, France  1959–present
# 13                        Luxembourg City, Luxembourg  1952–present
# 14                        Luxembourg City, Luxembourg  1994–present
# 15                                      Paris, France  1960–present
# 16                               San José, Costa Rica  1979–present
# 17                             The Hague, Netherlands  1945–present
# 18                             The Hague, Netherlands  2002–present
# 19                                   Arusha, Tanzania     1994−2015
# 20                             The Hague, Netherlands     1993−2017
# 21                        Nuremberg, post-war Germany     1945–1946
# 22                                       Tokyo, Japan     1946−1948
# 23                             The Hague, Netherlands  2012−present
# 24                                   Hamburg, Germany  1994–present
# 25                             The Hague, Netherlands     1922–1946
# 26                             Freetown, Sierra Leone  2013−present
# 27                                  Windhoek, Namibia     2005–2012
# 28                             Freetown, Sierra Leone     2002−2013
# 29                          Leidschendam, Netherlands  2009−present

# %%
df_ic.to_csv("df_ic.csv")

# %% [markdown]
# ## Text modifying
#
# We will try to extract the year of foundation.

# %% [markdown]
# ### Simple method

# %%
df_ic['Years active'].str.slice(0,4).astype('int')
# Out:
# 0     2006
# 1     1995
# 2     1975
# 3     2005
# 4     1994
# 5     1998
# 6     1998
# 7     1983
# 8     2015
# 9     2001
# 10    1967
# 11    1996
# 12    1959
# 13    1952
# 14    1994
# 15    1960
# 16    1979
# 17    1945
# 18    2002
# 19    1994
# 20    1993
# 21    1945
# 22    1946
# 23    2012
# 24    1994
# 25    1922
# 26    2013
# 27    2005
# 28    2002
# 29    2009
# Name: Years active, dtype: int64

# %%
df_ic['Founded'] = df_ic['Years active'].str.slice(0,4).astype('int')

# %%
[int(stri[:4]) for stri in df_ic['Years active']]
# Out:
# [2006,
#  1995,
#  1975,
#  2005,
#  1994,
#  1998,
#  1998,
#  1983,
#  2015,
#  2001,
#  1967,
#  1996,
#  1959,
#  1952,
#  1994,
#  1960,
#  1979,
#  1945,
#  2002,
#  1994,
#  1993,
#  1945,
#  1946,
#  2012,
#  1994,
#  1922,
#  2013,
#  2005,
#  2002,
#  2009]

# %% [markdown]
# ### Using regular expression
#
# Regular expression is really a powerful tool for extracting/modifying text in programming. There are several great introductions:
#
# 1. LinkedIn Learning (NLP with Python for Machine Learning Essential Training)
#   - https://www.linkedin.com/learning/nlp-with-python-for-machine-learning-essential-training/what-are-regular-expressions
#   - https://www.linkedin.com/learning/nlp-with-python-for-machine-learning-essential-training/learning-how-to-use-regular-expressions
#   - https://www.linkedin.com/learning/nlp-with-python-for-machine-learning-essential-training/regular-expression-replacements
#
# 2. YouTube
#   - https://www.youtube.com/watch?v=K8L6KVGG-7o

# %%
df_ic['Years active'].str.extract(r'^(\d{4})(.+)')
# Out:
#        0         1
# 0   2006  –present
# 1   1995  –present
# 2   1975  –present
# 3   2005  –present
# 4   1994  –present
# 5   1998  –present
# 6   1998  –present
# 7   1983  –present
# 8   2015  –present
# 9   2001  –present
# 10  1967  –present
# 11  1996  –present
# 12  1959  –present
# 13  1952  –present
# 14  1994  –present
# 15  1960  –present
# 16  1979  –present
# 17  1945  –present
# 18  2002  –present
# 19  1994     −2015
# 20  1993     −2017
# 21  1945     –1946
# 22  1946     −1948
# 23  2012  −present
# 24  1994  –present
# 25  1922     –1946
# 26  2013  −present
# 27  2005     –2012
# 28  2002     −2013
# 29  2009  −present

# %%
df_ic['Founded2'] = df_ic['Years active'].str.extract(r'^(\d{4})').astype(int)

# %%
df_ic
# Out:
#                                                  Name  \
# 0          African Court on Human and Peoples' Rights
# 1      Appellate Body of the World Trade Organization
# 2                            Benelux Court of Justice
# 3                          Caribbean Court of Justice
# 4                                  CIS Economic Court
# 5                             COMESA Court of Justice
# 6   Common Court of Justice and Arbitration of the...
# 7            Court of Justice of the Andean Community
# 8                Court of the Eurasian Economic Union
# 9                       East African Court of Justice
# 10                    Eastern Caribbean Supreme Court
# 11                            ECOWAS Court of Justice
# 12                     European Court of Human Rights
# 13                          European Court of Justice
# 14              European Free Trade Association Court
# 15                   European Nuclear Energy Tribunal
# 16               Inter-American Court of Human Rights
# 17                     International Court of Justice
# 18                       International Criminal Court
# 19         International Criminal Tribunal for Rwanda
# 20  International Criminal Tribunal for the former...
# 21                    International Military Tribunal
# 22   International Military Tribunal for the Far East
# 23  International Residual Mechanism for Criminal ...
# 24      International Tribunal for the Law of the Sea
# 25           Permanent Court of International Justice
# 26            Residual Special Court for Sierra Leone
# 27                                      SADC Tribunal
# 28                     Special Court for Sierra Leone
# 29                       Special Tribunal for Lebanon
#
#                              Subject matter and scope  \
# 0               Human rights within the African Union
# 1   Trade disputes within the World Trade Organiza...
# 2                   Trade disputes within the Benelux
# 3     General disputes within the Caribbean Community
# 4   Trade disputes and interpretation of treaties ...
# 5   Trade disputes within the Common Market for Ea...
# 6   Interpretation of OHADA treaties and uniform laws
# 7          Trade disputes within the Andean Community
# 8   Trade disputes and interpretation of treaties ...
# 9   Interpretation of East African Community treaties
# 10  General disputes within the Organisation of Ea...
# 11  Interpretation of Economic Community of West A...
# 12          Human rights within the Council of Europe
# 13               Interpretation of European Union law
# 14  Interpretation of European Free Trade Associat...
# 15            Nuclear energy disputes within the OECD
# 16  Human rights within the Organization of Americ...
# 17                     General disputes globally (UN)
# 18      Criminal prosecutions globally (Rome Statute)
# 19  Criminal prosecutions for the Rwandan genocide...
# 20   Criminal prosecutions for the Yugoslav Wars (UN)
# 21  Criminal prosecutions of Nazi German officials...
# 22  Criminal prosecutions of Imperial Japanese off...
# 23  Completing the Rwanda and Yugoslav Tribunals' ...
# 24                Maritime disputes globally (UNCLOS)
# 25      General disputes globally (League of Nations)
# 26  Completing the Special Court for Sierra Leone'...
# 27  Interpretation of Southern African Development...
# 28  Criminal prosecutions for the Sierra Leone Civ...
# 29  Criminal prosecutions for the assassination of...
#
#                                          Headquarters  Years active  Founded  \
# 0   Addis Ababa, Ethiopia (2006–7)Arusha, Tanzania...  2006–present     2006
# 1                                 Geneva, Switzerland  1995–present     1995
# 2                                   Brussels, Belgium  1975–present     1975
# 3                  Port of Spain, Trinidad and Tobago  2005–present     2005
# 4                                      Minsk, Belarus  1994–present     1994
# 5                                     Khartoum, Sudan  1998–present     1998
# 6                                Abidjan, Ivory Coast  1998–present     1998
# 7                                      Quito, Ecuador  1983–present     1983
# 8                                      Minsk, Belarus  2015–present     2015
# 9                                    Arusha, Tanzania  2001–present     2001
# 10                              Castries, Saint Lucia  1967–present     1967
# 11                                     Abuja, Nigeria  1996–present     1996
# 12                                 Strasbourg, France  1959–present     1959
# 13                        Luxembourg City, Luxembourg  1952–present     1952
# 14                        Luxembourg City, Luxembourg  1994–present     1994
# 15                                      Paris, France  1960–present     1960
# 16                               San José, Costa Rica  1979–present     1979
# 17                             The Hague, Netherlands  1945–present     1945
# 18                             The Hague, Netherlands  2002–present     2002
# 19                                   Arusha, Tanzania     1994−2015     1994
# 20                             The Hague, Netherlands     1993−2017     1993
# 21                        Nuremberg, post-war Germany     1945–1946     1945
# 22                                       Tokyo, Japan     1946−1948     1946
# 23                             The Hague, Netherlands  2012−present     2012
# 24                                   Hamburg, Germany  1994–present     1994
# 25                             The Hague, Netherlands     1922–1946     1922
# 26                             Freetown, Sierra Leone  2013−present     2013
# 27                                  Windhoek, Namibia     2005–2012     2005
# 28                             Freetown, Sierra Leone     2002−2013     2002
# 29                          Leidschendam, Netherlands  2009−present     2009
#
#     Founded2
# 0       2006
# 1       1995
# 2       1975
# 3       2005
# 4       1994
# 5       1998
# 6       1998
# 7       1983
# 8       2015
# 9       2001
# 10      1967
# 11      1996
# 12      1959
# 13      1952
# 14      1994
# 15      1960
# 16      1979
# 17      1945
# 18      2002
# 19      1994
# 20      1993
# 21      1945
# 22      1946
# 23      2012
# 24      1994
# 25      1922
# 26      2013
# 27      2005
# 28      2002
# 29      2009

# %%
df_ic['Ended'] = df_ic['Years active'].str.extract(r'(\d{4})$')

# %%
df_ic
# Out:
#                                                  Name  \
# 0          African Court on Human and Peoples' Rights
# 1      Appellate Body of the World Trade Organization
# 2                            Benelux Court of Justice
# 3                          Caribbean Court of Justice
# 4                                  CIS Economic Court
# 5                             COMESA Court of Justice
# 6   Common Court of Justice and Arbitration of the...
# 7            Court of Justice of the Andean Community
# 8                Court of the Eurasian Economic Union
# 9                       East African Court of Justice
# 10                    Eastern Caribbean Supreme Court
# 11                            ECOWAS Court of Justice
# 12                     European Court of Human Rights
# 13                          European Court of Justice
# 14              European Free Trade Association Court
# 15                   European Nuclear Energy Tribunal
# 16               Inter-American Court of Human Rights
# 17                     International Court of Justice
# 18                       International Criminal Court
# 19         International Criminal Tribunal for Rwanda
# 20  International Criminal Tribunal for the former...
# 21                    International Military Tribunal
# 22   International Military Tribunal for the Far East
# 23  International Residual Mechanism for Criminal ...
# 24      International Tribunal for the Law of the Sea
# 25           Permanent Court of International Justice
# 26            Residual Special Court for Sierra Leone
# 27                                      SADC Tribunal
# 28                     Special Court for Sierra Leone
# 29                       Special Tribunal for Lebanon
#
#                              Subject matter and scope  \
# 0               Human rights within the African Union
# 1   Trade disputes within the World Trade Organiza...
# 2                   Trade disputes within the Benelux
# 3     General disputes within the Caribbean Community
# 4   Trade disputes and interpretation of treaties ...
# 5   Trade disputes within the Common Market for Ea...
# 6   Interpretation of OHADA treaties and uniform laws
# 7          Trade disputes within the Andean Community
# 8   Trade disputes and interpretation of treaties ...
# 9   Interpretation of East African Community treaties
# 10  General disputes within the Organisation of Ea...
# 11  Interpretation of Economic Community of West A...
# 12          Human rights within the Council of Europe
# 13               Interpretation of European Union law
# 14  Interpretation of European Free Trade Associat...
# 15            Nuclear energy disputes within the OECD
# 16  Human rights within the Organization of Americ...
# 17                     General disputes globally (UN)
# 18      Criminal prosecutions globally (Rome Statute)
# 19  Criminal prosecutions for the Rwandan genocide...
# 20   Criminal prosecutions for the Yugoslav Wars (UN)
# 21  Criminal prosecutions of Nazi German officials...
# 22  Criminal prosecutions of Imperial Japanese off...
# 23  Completing the Rwanda and Yugoslav Tribunals' ...
# 24                Maritime disputes globally (UNCLOS)
# 25      General disputes globally (League of Nations)
# 26  Completing the Special Court for Sierra Leone'...
# 27  Interpretation of Southern African Development...
# 28  Criminal prosecutions for the Sierra Leone Civ...
# 29  Criminal prosecutions for the assassination of...
#
#                                          Headquarters  Years active  Founded  \
# 0   Addis Ababa, Ethiopia (2006–7)Arusha, Tanzania...  2006–present     2006
# 1                                 Geneva, Switzerland  1995–present     1995
# 2                                   Brussels, Belgium  1975–present     1975
# 3                  Port of Spain, Trinidad and Tobago  2005–present     2005
# 4                                      Minsk, Belarus  1994–present     1994
# 5                                     Khartoum, Sudan  1998–present     1998
# 6                                Abidjan, Ivory Coast  1998–present     1998
# 7                                      Quito, Ecuador  1983–present     1983
# 8                                      Minsk, Belarus  2015–present     2015
# 9                                    Arusha, Tanzania  2001–present     2001
# 10                              Castries, Saint Lucia  1967–present     1967
# 11                                     Abuja, Nigeria  1996–present     1996
# 12                                 Strasbourg, France  1959–present     1959
# 13                        Luxembourg City, Luxembourg  1952–present     1952
# 14                        Luxembourg City, Luxembourg  1994–present     1994
# 15                                      Paris, France  1960–present     1960
# 16                               San José, Costa Rica  1979–present     1979
# 17                             The Hague, Netherlands  1945–present     1945
# 18                             The Hague, Netherlands  2002–present     2002
# 19                                   Arusha, Tanzania     1994−2015     1994
# 20                             The Hague, Netherlands     1993−2017     1993
# 21                        Nuremberg, post-war Germany     1945–1946     1945
# 22                                       Tokyo, Japan     1946−1948     1946
# 23                             The Hague, Netherlands  2012−present     2012
# 24                                   Hamburg, Germany  1994–present     1994
# 25                             The Hague, Netherlands     1922–1946     1922
# 26                             Freetown, Sierra Leone  2013−present     2013
# 27                                  Windhoek, Namibia     2005–2012     2005
# 28                             Freetown, Sierra Leone     2002−2013     2002
# 29                          Leidschendam, Netherlands  2009−present     2009
#
#     Founded2 Ended
# 0       2006   NaN
# 1       1995   NaN
# 2       1975   NaN
# 3       2005   NaN
# 4       1994   NaN
# 5       1998   NaN
# 6       1998   NaN
# 7       1983   NaN
# 8       2015   NaN
# 9       2001   NaN
# 10      1967   NaN
# 11      1996   NaN
# 12      1959   NaN
# 13      1952   NaN
# 14      1994   NaN
# 15      1960   NaN
# 16      1979   NaN
# 17      1945   NaN
# 18      2002   NaN
# 19      1994  2015
# 20      1993  2017
# 21      1945  1946
# 22      1946  1948
# 23      2012   NaN
# 24      1994   NaN
# 25      1922  1946
# 26      2013   NaN
# 27      2005  2012
# 28      2002  2013
# 29      2009   NaN

# %% [markdown]
# ## Save the data

# %%
df_ic.to_csv("data_iternational_court.csv")

# %% [markdown]
# # List of MEPs
#
# In this part of demo, we will create a list of the Members of European Parliament (MEPs).
#
# The base url (list of MEPs with family name starting with letter 'a') is here:
# https://www.europarl.europa.eu/meps/en/full-list/a

# %% [markdown]
# ## Extract names
#
# - Scenario 2

# %%
url = "https://www.europarl.europa.eu/meps/en/full-list/a"
html = urlopen(url)
bs = BeautifulSoup(html, "html.parser")

# %%
name_tags = bs.select('#docMembersList .t-item')

mep_name = [item.get_text().strip() for item in name_tags]
mep_name
# Out:
# ['Magdalena ADAMOWICZ',
#  'Asim ADEMOV',
#  'Isabella ADINOLFI',
#  'Matteo ADINOLFI',
#  'Alex AGIUS SALIBA',
#  'Mazaly AGUILAR',
#  'Clara AGUILERA',
#  'Alviina ALAMETSÄ',
#  'João ALBUQUERQUE',
#  'Alexander ALEXANDROV YORDANOV',
#  'François ALFONSI',
#  'Atidzhe ALIEVA-VELI',
#  'Abir AL-SAHLANI',
#  'Álvaro AMARO',
#  'Andris AMERIKS',
#  'Christine ANDERSON',
#  'Rasmus ANDRESEN',
#  'Barry ANDREWS',
#  'Eric ANDRIEU',
#  'Mathilde ANDROUËT',
#  'Nikos ANDROULAKIS',
#  'Marc ANGEL',
#  'Gerolf ANNEMANS',
#  'Andrus ANSIP',
#  'Attila ARA-KOVÁCS',
#  'Maria ARENA',
#  'Pablo ARIAS ECHEVERRÍA',
#  'Pascal ARIMONT',
#  'Bartosz ARŁUKOWICZ',
#  'Konstantinos ARVANITIS',
#  'Anna-Michelle ASIMAKOPOULOU',
#  'Manon AUBRY',
#  'Margrete AUKEN',
#  'Petras AUŠTREVIČIUS',
#  'Carmen AVRAM',
#  'Malik AZMANI']

# %%
[t.get_text() for t in name_tags]
# Out:
# ['Magdalena ADAMOWICZ',
#  'Asim ADEMOV',
#  'Isabella ADINOLFI',
#  'Matteo ADINOLFI',
#  'Alex AGIUS SALIBA',
#  'Mazaly AGUILAR',
#  'Clara AGUILERA',
#  'Alviina ALAMETSÄ',
#  'João ALBUQUERQUE',
#  'Alexander ALEXANDROV YORDANOV',
#  'François ALFONSI',
#  'Atidzhe ALIEVA-VELI',
#  'Abir AL-SAHLANI',
#  'Álvaro AMARO',
#  'Andris AMERIKS',
#  'Christine ANDERSON',
#  'Rasmus ANDRESEN',
#  'Barry ANDREWS',
#  'Eric ANDRIEU',
#  'Mathilde ANDROUËT',
#  'Nikos ANDROULAKIS',
#  'Marc ANGEL',
#  'Gerolf ANNEMANS',
#  'Andrus ANSIP',
#  'Attila ARA-KOVÁCS',
#  'Maria ARENA',
#  'Pablo ARIAS ECHEVERRÍA',
#  'Pascal ARIMONT',
#  'Bartosz ARŁUKOWICZ',
#  'Konstantinos ARVANITIS',
#  'Anna-Michelle ASIMAKOPOULOU',
#  'Manon AUBRY',
#  'Margrete AUKEN',
#  'Petras AUŠTREVIČIUS',
#  'Carmen AVRAM',
#  'Malik AZMANI']

# %%
mep_name

# %% [markdown]
# ## Extract political groups and country names

# %%
#bs.select(".mb-25:nth-child(1)")
# Out:
# []

# %%
group_and_country = [item.get_text().strip() for item in bs.select('.mb-25')]
group_and_country
# Out:
# ["Group of the European People's Party (Christian Democrats)",
#  'Poland',
#  "Group of the European People's Party (Christian Democrats)",
#  'Bulgaria',
#  "Group of the European People's Party (Christian Democrats)",
#  'Italy',
#  'Identity and Democracy Group',
#  'Italy',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Malta',
#  'European Conservatives and Reformists Group',
#  'Spain',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Spain',
#  'Group of the Greens/European Free Alliance',
#  'Finland',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Portugal',
#  "Group of the European People's Party (Christian Democrats)",
#  'Bulgaria',
#  'Group of the Greens/European Free Alliance',
#  'France',
#  'Renew Europe Group',
#  'Bulgaria',
#  'Renew Europe Group',
#  'Sweden',
#  "Group of the European People's Party (Christian Democrats)",
#  'Portugal',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Latvia',
#  'Identity and Democracy Group',
#  'Germany',
#  'Group of the Greens/European Free Alliance',
#  'Germany',
#  'Renew Europe Group',
#  'Ireland',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'France',
#  'Identity and Democracy Group',
#  'France',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Greece',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Luxembourg',
#  'Identity and Democracy Group',
#  'Belgium',
#  'Renew Europe Group',
#  'Estonia',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Hungary',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Belgium',
#  "Group of the European People's Party (Christian Democrats)",
#  'Spain',
#  "Group of the European People's Party (Christian Democrats)",
#  'Belgium',
#  "Group of the European People's Party (Christian Democrats)",
#  'Poland',
#  'The Left group in the European Parliament - GUE/NGL',
#  'Greece',
#  "Group of the European People's Party (Christian Democrats)",
#  'Greece',
#  'The Left group in the European Parliament - GUE/NGL',
#  'France',
#  'Group of the Greens/European Free Alliance',
#  'Denmark',
#  'Renew Europe Group',
#  'Lithuania',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Romania',
#  'Renew Europe Group',
#  'Netherlands']

# %%
len(group_and_country)

# %%
for i, text in enumerate(group_and_country):
  print(i, text)
# Out:
# 0 Group of the European People's Party (Christian Democrats)
# 1 Poland
# 2 Group of the European People's Party (Christian Democrats)
# 3 Bulgaria
# 4 Group of the European People's Party (Christian Democrats)
# 5 Italy
# 6 Identity and Democracy Group
# 7 Italy
# 8 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 9 Malta
# 10 European Conservatives and Reformists Group
# 11 Spain
# 12 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 13 Spain
# 14 Group of the Greens/European Free Alliance
# 15 Finland
# 16 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 17 Portugal
# 18 Group of the European People's Party (Christian Democrats)
# 19 Bulgaria
# 20 Group of the Greens/European Free Alliance
# 21 France
# 22 Renew Europe Group
# 23 Bulgaria
# 24 Renew Europe Group
# 25 Sweden
# 26 Group of the European People's Party (Christian Democrats)
# 27 Portugal
# 28 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 29 Latvia
# 30 Identity and Democracy Group
# 31 Germany
# 32 Group of the Greens/European Free Alliance
# 33 Germany
# 34 Renew Europe Group
# 35 Ireland
# 36 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 37 France
# 38 Identity and Democracy Group
# 39 France
# 40 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 41 Greece
# 42 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 43 Luxembourg
# 44 Identity and Democracy Group
# 45 Belgium
# 46 Renew Europe Group
# 47 Estonia
# 48 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 49 Hungary
# 50 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 51 Belgium
# 52 Group of the European People's Party (Christian Democrats)
# 53 Spain
# 54 Group of the European People's Party (Christian Democrats)
# 55 Belgium
# 56 Group of the European People's Party (Christian Democrats)
# 57 Poland
# 58 The Left group in the European Parliament - GUE/NGL
# 59 Greece
# 60 Group of the European People's Party (Christian Democrats)
# 61 Greece
# 62 The Left group in the European Parliament - GUE/NGL
# 63 France
# 64 Group of the Greens/European Free Alliance
# 65 Denmark
# 66 Renew Europe Group
# 67 Lithuania
# 68 Group of the Progressive Alliance of Socialists and Democrats in the European Parliament
# 69 Romania
# 70 Renew Europe Group
# 71 Netherlands

# %%
mep_group = [text for i, text in enumerate(group_and_country) if i % 2 == 0]
mep_group
# Out:
# ["Group of the European People's Party (Christian Democrats)",
#  "Group of the European People's Party (Christian Democrats)",
#  "Group of the European People's Party (Christian Democrats)",
#  'Identity and Democracy Group',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'European Conservatives and Reformists Group',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Group of the Greens/European Free Alliance',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  "Group of the European People's Party (Christian Democrats)",
#  'Group of the Greens/European Free Alliance',
#  'Renew Europe Group',
#  'Renew Europe Group',
#  "Group of the European People's Party (Christian Democrats)",
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Identity and Democracy Group',
#  'Group of the Greens/European Free Alliance',
#  'Renew Europe Group',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Identity and Democracy Group',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Identity and Democracy Group',
#  'Renew Europe Group',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  "Group of the European People's Party (Christian Democrats)",
#  "Group of the European People's Party (Christian Democrats)",
#  "Group of the European People's Party (Christian Democrats)",
#  'The Left group in the European Parliament - GUE/NGL',
#  "Group of the European People's Party (Christian Democrats)",
#  'The Left group in the European Parliament - GUE/NGL',
#  'Group of the Greens/European Free Alliance',
#  'Renew Europe Group',
#  'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament',
#  'Renew Europe Group']

# %%
country = [text for i, text in enumerate(group_and_country) if i % 2 == 1]
country
# Out:
# ['Poland',
#  'Bulgaria',
#  'Italy',
#  'Italy',
#  'Malta',
#  'Spain',
#  'Spain',
#  'Finland',
#  'Portugal',
#  'Bulgaria',
#  'France',
#  'Bulgaria',
#  'Sweden',
#  'Portugal',
#  'Latvia',
#  'Germany',
#  'Germany',
#  'Ireland',
#  'France',
#  'France',
#  'Greece',
#  'Luxembourg',
#  'Belgium',
#  'Estonia',
#  'Hungary',
#  'Belgium',
#  'Spain',
#  'Belgium',
#  'Poland',
#  'Greece',
#  'Greece',
#  'France',
#  'Denmark',
#  'Lithuania',
#  'Romania',
#  'Netherlands']

# %% [markdown]
# ## Extract party name

# %%
items = [item.get_text().strip() for item in bs.select('.sln-additional-info')]
party_name = [text for i, text in enumerate(items) if i % 3 == 2]
party_name
# Out:
# ['Independent',
#  'Citizens for European Development of Bulgaria',
#  'Forza Italia',
#  'Lega',
#  'Partit Laburista',
#  'VOX',
#  'Partido Socialista Obrero Español',
#  'Vihreä liitto',
#  'Partido Socialista',
#  'Union of Democratic Forces',
#  'Régions et Peuples Solidaires',
#  'Movement for Rights and Freedoms',
#  'Centerpartiet',
#  'Partido Social Democrata',
#  'Gods kalpot Rīgai',
#  'Alternative für Deutschland',
#  'Bündnis 90/Die Grünen',
#  'Fianna Fáil Party',
#  'Parti socialiste',
#  'Rassemblement national',
#  'PASOK-KINAL',
#  'Parti ouvrier socialiste luxembourgeois',
#  'Vlaams Belang',
#  'Eesti Reformierakond',
#  'Demokratikus Koalíció',
#  'Parti Socialiste',
#  'Partido Popular',
#  'Christlich Soziale Partei',
#  'Platforma Obywatelska',
#  'Coalition of the Radical Left',
#  'Nea Demokratia',
#  'La France Insoumise',
#  'Socialistisk Folkeparti',
#  'Lietuvos Respublikos liberalų sąjūdis',
#  'Partidul Social Democrat',
#  'Volkspartij voor Vrijheid en Democratie']

# %% [markdown]
# ## Extract link to the individual pages

# %%
bs.select('a.erpl_member-list-item-content')[0]
# Out:
# <a class="erpl_member-list-item-content mb-2 t-y-block" href="https://www.europarl.europa.eu/meps/en/197490" itemprop="url">
# <div>
# <div class="erpl_image-frame mb-2">
# <img alt="" aria-hidden="true" src="/commonFrontResources/evostrap/4.0.1/lib/assets/img/frame/portraitsize_thumb.png"/>
# <span>
# <picture>
# <img alt="Magdalena ADAMOWICZ" loading="lazy" src="https://www.europarl.europa.eu/mepphoto/197490.jpg"/>
# </picture>
# </span>
# </div>
# <div class="erpl_title-h5 t-item">Magdalena ADAMOWICZ</div>
# <div>
# <div class="sln-additional-info mb-25">Group of the European People's Party (Christian Democrats)</div>
# <div class="sln-additional-info mb-25">Poland</div>
# <div class="sln-additional-info ">Independent</div>
# </div>
# </div>
# </a>

# %%
first_item = bs.select('a.erpl_member-list-item-content')[0]

# %%
first_item['href']
# Out:
# 'https://www.europarl.europa.eu/meps/en/197490'

# %%
page_url = [item['href'] for item in bs.select('a.erpl_member-list-item-content')]

# %%
page_url
# Out:
# ['https://www.europarl.europa.eu/meps/en/197490',
#  'https://www.europarl.europa.eu/meps/en/189525',
#  'https://www.europarl.europa.eu/meps/en/124831',
#  'https://www.europarl.europa.eu/meps/en/197826',
#  'https://www.europarl.europa.eu/meps/en/197403',
#  'https://www.europarl.europa.eu/meps/en/198096',
#  'https://www.europarl.europa.eu/meps/en/125045',
#  'https://www.europarl.europa.eu/meps/en/204335',
#  'https://www.europarl.europa.eu/meps/en/237224',
#  'https://www.europarl.europa.eu/meps/en/197836',
#  'https://www.europarl.europa.eu/meps/en/96750',
#  'https://www.europarl.europa.eu/meps/en/197848',
#  'https://www.europarl.europa.eu/meps/en/197400',
#  'https://www.europarl.europa.eu/meps/en/197746',
#  'https://www.europarl.europa.eu/meps/en/197783',
#  'https://www.europarl.europa.eu/meps/en/197475',
#  'https://www.europarl.europa.eu/meps/en/197448',
#  'https://www.europarl.europa.eu/meps/en/204332',
#  'https://www.europarl.europa.eu/meps/en/113892',
#  'https://www.europarl.europa.eu/meps/en/197691',
#  'https://www.europarl.europa.eu/meps/en/125110',
#  'https://www.europarl.europa.eu/meps/en/202073',
#  'https://www.europarl.europa.eu/meps/en/124973',
#  'https://www.europarl.europa.eu/meps/en/124696',
#  'https://www.europarl.europa.eu/meps/en/197587',
#  'https://www.europarl.europa.eu/meps/en/124936',
#  'https://www.europarl.europa.eu/meps/en/96808',
#  'https://www.europarl.europa.eu/meps/en/24922',
#  'https://www.europarl.europa.eu/meps/en/197492',
#  'https://www.europarl.europa.eu/meps/en/197701',
#  'https://www.europarl.europa.eu/meps/en/197695',
#  'https://www.europarl.europa.eu/meps/en/197533',
#  'https://www.europarl.europa.eu/meps/en/28161',
#  'https://www.europarl.europa.eu/meps/en/124766',
#  'https://www.europarl.europa.eu/meps/en/197651',
#  'https://www.europarl.europa.eu/meps/en/197781']

# %% [markdown]
# ## Combine

# %%
df_meps = pd.DataFrame(mep_name, columns = ['mep_name'])

# %%
df_meps.head()
# Out:
#               mep_name
# 0  Magdalena ADAMOWICZ
# 1          Asim ADEMOV
# 2    Isabella ADINOLFI
# 3      Matteo ADINOLFI
# 4    Alex AGIUS SALIBA

# %%
df_meps['group'] = mep_group
df_meps['country'] = country
df_meps['party'] = party_name
df_meps['page_url'] = page_url
df_meps.head()
# Out:
#               mep_name                                              group  \
# 0  Magdalena ADAMOWICZ  Group of the European People's Party (Christia...
# 1          Asim ADEMOV  Group of the European People's Party (Christia...
# 2    Isabella ADINOLFI  Group of the European People's Party (Christia...
# 3      Matteo ADINOLFI                       Identity and Democracy Group
# 4    Alex AGIUS SALIBA  Group of the Progressive Alliance of Socialist...
#
#     country                                          party  \
# 0    Poland                                    Independent
# 1  Bulgaria  Citizens for European Development of Bulgaria
# 2     Italy                                   Forza Italia
# 3     Italy                                           Lega
# 4     Malta                               Partit Laburista
#
#                                         page_url
# 0  https://www.europarl.europa.eu/meps/en/197490
# 1  https://www.europarl.europa.eu/meps/en/189525
# 2  https://www.europarl.europa.eu/meps/en/124831
# 3  https://www.europarl.europa.eu/meps/en/197826
# 4  https://www.europarl.europa.eu/meps/en/197403

# %% [markdown]
# ## Save the data

# %%
df_meps.to_csv("data_mep_list_a.csv")
